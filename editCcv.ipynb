# %%
import pandas as pd

# %%
prefix = '14-9F-3C-DA-5B-26'
output_path = '/Volumes/hex/ST-1233329802-res/'
file = pd.read_csv(output_path + prefix + '.csv')

file.head(10)
# Out:
#          time  window   accX  accX_std  accY  accY_std  accZ  accZ_std  gyrX  \
# 0  1537427588      60  -2.63      5.72 -6.09      3.42  2.21      3.42 -3.86
# 1  1537427648      59  -4.04      3.80 -6.98      2.31 -0.86      2.31 -1.44
# 2  1537427707      60   0.35      1.45 -9.31      0.81 -3.01      0.81  0.03
# 3  1537427767     120  -4.51      4.72 -6.16      2.57  1.07      2.57 -0.40
# 4  1537427887    3438   6.36      5.85 -1.83      4.15  0.67      4.15  3.50
# 5  1537431325     147    NaN       NaN   NaN       NaN   NaN       NaN   NaN
# 6  1537431472      85  -0.59      4.63  4.72      3.43  7.79      3.43 -1.77
# 7  1537431557      60  10.00      0.59  0.00      0.91  0.19      0.91 -0.08
# 8  1537431617      59  10.01      0.07 -0.01      0.06  0.22      0.06 -0.07
# 9  1537431676      60  10.01      0.03 -0.02      0.04  0.22      0.04 -0.05
#
#    gyrX_std  gyrY  gyrY_std  gyrZ  gyrZ_std  heartR  heartR_std  \
# 0     79.85 -3.27     46.53 -0.50     59.03   58.78       43.50
# 1     80.40  2.52     35.61 -0.64     33.67   98.48        2.87
# 2     20.70  0.09     16.15  0.11     17.86   85.20       13.78
# 3    102.96 -0.84     34.28 -1.67     30.24   78.27        4.07
# 4     92.47  0.54     82.14 -1.19     45.57     NaN         NaN
# 5       NaN   NaN       NaN   NaN       NaN     NaN         NaN
# 6     40.92 -0.82     46.57 -2.38     52.58     NaN         NaN
# 7     13.58 -0.07     12.51  0.06     12.75     NaN         NaN
# 8      0.42 -0.07      0.34  0.03      0.22     NaN         NaN
# 9      0.15 -0.02      0.16  0.03      0.11     NaN         NaN
#
#    AirTemperature  AT_std  PlethysmogramGreen    ple_std
# 0           28.67    0.58          2165277.05  504679.50
# 1           29.86    0.23          2228357.74  209617.92
# 2           30.43    0.13          1888259.33  110861.97
# 3           30.81    0.10          2214220.42  242204.13
# 4           31.00    0.02          2712535.35  689277.46
# 5             NaN     NaN                 NaN        NaN
# 6           28.07    0.04          2236358.31  407439.34
# 7           28.36    0.02          1401685.47  253898.21
# 8           28.35    0.02          1401525.92     980.65
# 9           28.30    0.02          1401485.65     979.98

# %%
column_names = list(file.columns.values)
column_names
# Out:
# ['time',
#  'window',
#  'accX',
#  'accX_std',
#  'accY',
#  'accY_std',
#  'accZ',
#  'accZ_std',
#  'gyrX',
#  'gyrX_std',
#  'gyrY',
#  'gyrY_std',
#  'gyrZ',
#  'gyrZ_std',
#  'heartR',
#  'heartR_std',
#  'AirTemperature',
#  'AT_std',
#  'PlethysmogramGreen',
#  'ple_std']

# %%
time_and_window = file.loc[:,'time':'window']
rest_values = file.loc[:,'accX':'ple_std']
# 1- get indices where all elements are NaN
idx = rest_values.index[rest_values.isnull().all(1)]
# nans = rest_values.loc[idx]

# 2- drop those elements
file_nan_free = file.drop(idx)
rv_nan_free = rest_values.dropna(how='all')
# 3- make sure both have the same number of rows
print(file_nan_free.shape)
print(nan_free.shape)
# Out:
# (125304, 20)
# (125304, 18)

# %%
# impute the  missing values with the median
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')

# %%
imputer.fit(file_nan_free)
imputer.statistics_
# Out:
# array([ 1.55149587e+09,  6.00000000e+01,  3.39000000e+00,  3.00000000e-02,
#        -3.32000000e+00,  3.00000000e-02,  3.73000000e+00,  3.00000000e-02,
#        -4.00000000e-02,  2.80000000e-01,  0.00000000e+00,  2.20000000e-01,
#         3.00000000e-02,  1.90000000e-01,  6.39900000e+01,  1.48000000e+00,
#         1.59830000e+02,  2.51000000e+00,  4.19330264e+06,  8.32000000e+01])

# %%
file_imputed = imputer.transform(file_nan_free)
file_imputed = pd.DataFrame(file_imputed, columns=file_nan_free.columns, index=file_nan_free.index)
file_imputed
# Out:
#                 time        window  accX  accX_std  accY  accY_std  accZ  \
# 0       1.537428e+09  6.000000e+01 -2.63      5.72 -6.09      3.42  2.21
# 1       1.537428e+09  5.900000e+01 -4.04      3.80 -6.98      2.31 -0.86
# 2       1.537428e+09  6.000000e+01  0.35      1.45 -9.31      0.81 -3.01
# 3       1.537428e+09  1.200000e+02 -4.51      4.72 -6.16      2.57  1.07
# 4       1.537428e+09  3.438000e+03  6.36      5.85 -1.83      4.15  0.67
# ...              ...           ...   ...       ...   ...       ...   ...
# 126205  1.564264e+09  5.800000e+01  6.76      0.05 -6.93      0.07 -0.63
# 126206  1.564264e+09  5.900000e+01  7.29      0.20 -6.36      0.26 -0.65
# 126207  1.564264e+09  5.800000e+01  7.69      0.04 -5.87      0.08 -0.75
# 126208  1.564264e+09  7.900000e+01  3.39      0.03 -3.32      0.03  3.73
# 126209  1.564264e+09 -1.564264e+09  7.69      0.14 -5.86      0.26 -0.72
#
#         accZ_std  gyrX  gyrX_std  gyrY  gyrY_std  gyrZ  gyrZ_std  heartR  \
# 0           3.42 -3.86     79.85 -3.27     46.53 -0.50     59.03   58.78
# 1           2.31 -1.44     80.40  2.52     35.61 -0.64     33.67   98.48
# 2           0.81  0.03     20.70  0.09     16.15  0.11     17.86   85.20
# 3           2.57 -0.40    102.96 -0.84     34.28 -1.67     30.24   78.27
# 4           4.15  3.50     92.47  0.54     82.14 -1.19     45.57   63.99
# ...          ...   ...       ...   ...       ...   ...       ...     ...
# 126205      0.07 -0.14      1.10 -0.03      0.49  0.06      0.50   63.99
# 126206      0.26 -0.10      2.10 -0.01      2.27 -0.01      2.26   63.99
# 126207      0.08 -0.16      0.93  0.01      0.58  0.02      0.50   63.99
# 126208      0.03 -0.04      0.28  0.00      0.22  0.03      0.19   63.99
# 126209      0.26 -0.16      4.06  0.00      2.04  0.03      1.68   63.99
#
#         heartR_std  AirTemperature  AT_std  PlethysmogramGreen    ple_std
# 0            43.50           28.67    0.58          2165277.05  504679.50
# 1             2.87           29.86    0.23          2228357.74  209617.92
# 2            13.78           30.43    0.13          1888259.33  110861.97
# 3             4.07           30.81    0.10          2214220.42  242204.13
# 4             1.48           31.00    0.02          2712535.35  689277.46
# ...            ...             ...     ...                 ...        ...
# 126205        1.48          157.54    2.56          4193094.55      78.95
# 126206        1.48          157.82    2.52          4193108.26      83.06
# 126207        1.48          157.77    2.55          4193141.01      78.35
# 126208        1.48          157.78    2.64          4193137.59      81.87
# 126209        1.48          158.67    1.80          4193126.51      88.96
#
# [125304 rows x 20 columns]

# %%
# saving the imputed df and merge it with the evening_protocol for further processing
file_imputed.to_csv(output_path + prefix + '_imputed.csv')

# %%
# load complete df
data_2 = pd.read_csv(output_path + 'complete_2.0.csv')
data_3 = pd.read_csv(output_path + 'complete_3.0.csv')

data_2.columns
# Out:
# Index(['time', 'accX', 'accX_std', 'accY', 'accY_std', 'accZ', 'accZ_std',
#        'gyrX', 'gyrX_std', 'gyrY', 'gyrY_std', 'gyrZ', 'gyrZ_std', 'heartR',
#        'heartR_std', 'AirTemperature', 'AT_std', 'PlethysmogramGreen',
#        'ple_std', 'mood', 'tense', 'tired', 'period', 'rumination',
#        'socialize', 'socialize_val', 'sport_time', 'work_time', 'day_sleep',
#        'phq_1', 'phq_2'],
#       dtype='object')

# %%
data_3.columns
# Out:
# Index(['time', 'accX', 'accX_std', 'accY', 'accY_std', 'accZ', 'accZ_std',
#        'gyrX', 'gyrX_std', 'gyrY', 'gyrY_std', 'gyrZ', 'gyrZ_std', 'heartR',
#        'heartR_std', 'AirTemperature', 'AT_std', 'PlethysmogramGreen',
#        'ple_std', 'mood', 'tense', 'tired', 'rumination', 'socialize',
#        'socialize_val', 'work_time', 'phq_1', 'phq_2'],
#       dtype='object')

# %%
# extract numeric features for random forest
rf_time_2 = data_[['time']]
rf_features_2 = data_2.loc[:,'accX':'day_sleep']
rf_features_2
# Out:
#         accX  accX_std  accY  accY_std  accZ  accZ_std  gyrX  gyrX_std  gyrY  \
# 0      -2.63      5.72 -6.09      3.42  2.21      3.42 -3.86     79.85 -3.27
# 1      -4.04      3.80 -6.98      2.31 -0.86      2.31 -1.44     80.40  2.52
# 2       0.35      1.45 -9.31      0.81 -3.01      0.81  0.03     20.70  0.09
# 3      -4.51      4.72 -6.16      2.57  1.07      2.57 -0.40    102.96 -0.84
# 4       6.36      5.85 -1.83      4.15  0.67      4.15  3.50     92.47  0.54
# ...      ...       ...   ...       ...   ...       ...   ...       ...   ...
# 122079 -3.00      0.03  8.23      0.03 -4.88      0.03 -0.07      0.13  0.04
# 122080 -2.96      0.03  8.27      0.03 -4.84      0.03 -0.05      0.13  0.05
# 122081 -2.95      0.03  8.28      0.03 -4.82      0.03 -0.06      0.12  0.04
# 122082  3.39      0.03 -3.32      0.03  3.73      0.03 -0.04      0.28  0.00
# 122083 -2.94      0.03  8.29      0.03 -4.82      0.03 -0.05      0.12  0.04
#
#         gyrY_std  ...  mood  tense  tired  period  rumination  socialize  \
# 0          46.53  ...     2      4      1       0           4         37
# 1          35.61  ...     2      4      1       0           4         37
# 2          16.15  ...     2      4      1       0           4         37
# 3          34.28  ...     2      4      1       0           4         37
# 4          82.14  ...     2      4      1       0           4         37
# ...          ...  ...   ...    ...    ...     ...         ...        ...
# 122079      0.14  ...     2      2      1       0           6         81
# 122080      0.12  ...     2      2      1       0           6         81
# 122081      0.11  ...     2      2      1       0           6         81
# 122082      0.22  ...     2      2      1       0           6         81
# 122083      0.11  ...     2      2      1       0           6         81
#
#         socialize_val  sport_time  work_time  day_sleep
# 0                  49           0        240          0
# 1                  49           0        240          0
# 2                  49           0        240          0
# 3                  49           0        240          0
# 4                  49           0        240          0
# ...               ...         ...        ...        ...
# 122079             54           0         75          0
# 122080             54           0         75          0
# 122081             54           0         75          0
# 122082             54           0         75          0
# 122083             54           0         75          0
#
# [122084 rows x 28 columns]

# %%
# extract numeric features for random forest
rf_time_3 = data_3[['time']]
rf_features_3 = data_3.loc[:,'accX':'work_time']
rf_features_3
# Out:
#         accX  accX_std  accY  accY_std  accZ  accZ_std  gyrX  gyrX_std  gyrY  \
# 0      -2.63      5.72 -6.09      3.42  2.21      3.42 -3.86     79.85 -3.27
# 1      -4.04      3.80 -6.98      2.31 -0.86      2.31 -1.44     80.40  2.52
# 2       0.35      1.45 -9.31      0.81 -3.01      0.81  0.03     20.70  0.09
# 3      -4.51      4.72 -6.16      2.57  1.07      2.57 -0.40    102.96 -0.84
# 4       6.36      5.85 -1.83      4.15  0.67      4.15  3.50     92.47  0.54
# ...      ...       ...   ...       ...   ...       ...   ...       ...   ...
# 122079 -3.00      0.03  8.23      0.03 -4.88      0.03 -0.07      0.13  0.04
# 122080 -2.96      0.03  8.27      0.03 -4.84      0.03 -0.05      0.13  0.05
# 122081 -2.95      0.03  8.28      0.03 -4.82      0.03 -0.06      0.12  0.04
# 122082  3.39      0.03 -3.32      0.03  3.73      0.03 -0.04      0.28  0.00
# 122083 -2.94      0.03  8.29      0.03 -4.82      0.03 -0.05      0.12  0.04
#
#         gyrY_std  ...  AT_std  PlethysmogramGreen    ple_std  mood  tense  \
# 0          46.53  ...    0.58          2165277.05  504679.50     2      4
# 1          35.61  ...    0.23          2228357.74  209617.92     2      4
# 2          16.15  ...    0.13          1888259.33  110861.97     2      4
# 3          34.28  ...    0.10          2214220.42  242204.13     2      4
# 4          82.14  ...    0.02          2712535.35  689277.46     2      4
# ...          ...  ...     ...                 ...        ...   ...    ...
# 122079      0.14  ...    2.47          4193332.82      81.15     2      2
# 122080      0.12  ...    2.56          4193344.91      81.45     2      2
# 122081      0.11  ...    2.52          4193365.35      82.38     2      2
# 122082      0.22  ...    2.66          4193302.64      83.20     2      2
# 122083      0.11  ...    2.54          4193353.89      84.20     2      2
#
#         tired  rumination  socialize  socialize_val  work_time
# 0           1           4         37             49        240
# 1           1           4         37             49        240
# 2           1           4         37             49        240
# 3           1           4         37             49        240
# 4           1           4         37             49        240
# ...       ...         ...        ...            ...        ...
# 122079      1           6         81             54         75
# 122080      1           6         81             54         75
# 122081      1           6         81             54         75
# 122082      1           6         81             54         75
# 122083      1           6         81             54         75
#
# [122084 rows x 25 columns]

# %%
# standardization for the data
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
result_2 = scaler.fit_transform(rf_features_2)
rf_features_std_2 = pd.DataFrame(result_2, columns=rf_features_2.columns, index=rf_features_2.index).astype(np.float32)
rf_features_std_2
# Out:
# /Users/Hesham/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#             accX  accX_std      accY  accY_std      accZ  accZ_std      gyrX  \
# 0       0.369890  0.627753  0.189995  0.364807  0.606872  0.364807  0.196964
# 1       0.299601  0.416300  0.145023  0.245708  0.451743  0.245708  0.240694
# 2       0.518445  0.157489  0.027287  0.084764  0.343103  0.084764  0.267257
# 3       0.276171  0.517621  0.186458  0.273605  0.549267  0.273605  0.259487
# 4       0.818046  0.642070  0.405255  0.443133  0.529055  0.443133  0.329960
# ...          ...       ...       ...       ...       ...       ...       ...
# 122079  0.351446  0.001101  0.913593  0.001073  0.248610  0.001073  0.265450
# 122080  0.353440  0.001101  0.915614  0.001073  0.250632  0.001073  0.265811
# 122081  0.353938  0.001101  0.916119  0.001073  0.251642  0.001073  0.265631
# 122082  0.669990  0.001101  0.329965  0.001073  0.683679  0.001073  0.265992
# 122083  0.354437  0.001101  0.916625  0.001073  0.251642  0.001073  0.265811
#
#         gyrX_std      gyrY  gyrY_std  ...  mood  tense  tired  period  \
# 0       0.475552  0.362209  0.408265  ...   0.5    0.8   0.25     0.0
# 1       0.478828  0.504294  0.312451  ...   0.5    0.8   0.25     0.0
# 2       0.123280  0.444663  0.141704  ...   0.5    0.8   0.25     0.0
# 3       0.613186  0.421840  0.300781  ...   0.5    0.8   0.25     0.0
# 4       0.550712  0.455706  0.720716  ...   0.5    0.8   0.25     0.0
# ...          ...       ...       ...  ...   ...    ...    ...     ...
# 122079  0.000774  0.443436  0.001228  ...   0.5    0.4   0.25     0.0
# 122080  0.000774  0.443681  0.001053  ...   0.5    0.4   0.25     0.0
# 122081  0.000715  0.443436  0.000965  ...   0.5    0.4   0.25     0.0
# 122082  0.001668  0.442454  0.001930  ...   0.5    0.4   0.25     0.0
# 122083  0.000715  0.443436  0.000965  ...   0.5    0.4   0.25     0.0
#
#         rumination  socialize  socialize_val  sport_time  work_time  day_sleep
# 0         0.285714   0.325843       0.346667         0.0    0.50000        0.0
# 1         0.285714   0.325843       0.346667         0.0    0.50000        0.0
# 2         0.285714   0.325843       0.346667         0.0    0.50000        0.0
# 3         0.285714   0.325843       0.346667         0.0    0.50000        0.0
# 4         0.285714   0.325843       0.346667         0.0    0.50000        0.0
# ...            ...        ...            ...         ...        ...        ...
# 122079    0.571429   0.820225       0.413333         0.0    0.15625        0.0
# 122080    0.571429   0.820225       0.413333         0.0    0.15625        0.0
# 122081    0.571429   0.820225       0.413333         0.0    0.15625        0.0
# 122082    0.571429   0.820225       0.413333         0.0    0.15625        0.0
# 122083    0.571429   0.820225       0.413333         0.0    0.15625        0.0
#
# [122084 rows x 28 columns]

# %%
result_3 = scaler.fit_transform(rf_features_3)
rf_features_std_3 = pd.DataFrame(result_3, columns=rf_features_3.columns, index=rf_features_3.index).astype(np.float32)
rf_features_std_3
# Out:
# /Users/Hesham/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#             accX  accX_std      accY  accY_std      accZ  accZ_std      gyrX  \
# 0       0.369890  0.627753  0.189995  0.364807  0.606872  0.364807  0.196964
# 1       0.299601  0.416300  0.145023  0.245708  0.451743  0.245708  0.240694
# 2       0.518445  0.157489  0.027287  0.084764  0.343103  0.084764  0.267257
# 3       0.276171  0.517621  0.186458  0.273605  0.549267  0.273605  0.259487
# 4       0.818046  0.642070  0.405255  0.443133  0.529055  0.443133  0.329960
# ...          ...       ...       ...       ...       ...       ...       ...
# 122079  0.351446  0.001101  0.913593  0.001073  0.248610  0.001073  0.265450
# 122080  0.353440  0.001101  0.915614  0.001073  0.250632  0.001073  0.265811
# 122081  0.353938  0.001101  0.916119  0.001073  0.251642  0.001073  0.265631
# 122082  0.669990  0.001101  0.329965  0.001073  0.683679  0.001073  0.265992
# 122083  0.354437  0.001101  0.916625  0.001073  0.251642  0.001073  0.265811
#
#         gyrX_std      gyrY  gyrY_std  ...    AT_std  PlethysmogramGreen  \
# 0       0.475552  0.362209  0.408265  ...  0.035692            0.028073
# 1       0.478828  0.504294  0.312451  ...  0.014154            0.029042
# 2       0.123280  0.444663  0.141704  ...  0.008000            0.023814
# 3       0.613186  0.421840  0.300781  ...  0.006154            0.028825
# 4       0.550712  0.455706  0.720716  ...  0.001231            0.036486
# ...          ...       ...       ...  ...       ...                 ...
# 122079  0.000774  0.443436  0.001228  ...  0.152000            0.059251
# 122080  0.000774  0.443681  0.001053  ...  0.157538            0.059251
# 122081  0.000715  0.443436  0.000965  ...  0.155077            0.059251
# 122082  0.001668  0.442454  0.001930  ...  0.163692            0.059250
# 122083  0.000715  0.443436  0.000965  ...  0.156308            0.059251
#
#              ple_std  mood  tense  tired  rumination  socialize  \
# 0       3.752788e-04   0.5    0.8   0.25    0.285714   0.325843
# 1       1.558715e-04   0.5    0.8   0.25    0.285714   0.325843
# 2       8.243678e-05   0.5    0.8   0.25    0.285714   0.325843
# 3       1.801026e-04   0.5    0.8   0.25    0.285714   0.325843
# 4       5.125456e-04   0.5    0.8   0.25    0.285714   0.325843
# ...              ...   ...    ...    ...         ...        ...
# 122079  6.034301e-08   0.5    0.4   0.25    0.571429   0.820225
# 122080  6.056609e-08   0.5    0.4   0.25    0.571429   0.820225
# 122081  6.125764e-08   0.5    0.4   0.25    0.571429   0.820225
# 122082  6.186738e-08   0.5    0.4   0.25    0.571429   0.820225
# 122083  6.261099e-08   0.5    0.4   0.25    0.571429   0.820225
#
#         socialize_val  work_time
# 0            0.346667    0.50000
# 1            0.346667    0.50000
# 2            0.346667    0.50000
# 3            0.346667    0.50000
# 4            0.346667    0.50000
# ...               ...        ...
# 122079       0.413333    0.15625
# 122080       0.413333    0.15625
# 122081       0.413333    0.15625
# 122082       0.413333    0.15625
# 122083       0.413333    0.15625
#
# [122084 rows x 25 columns]

# %%
rf_features_std_3.dtypes
# Out:
# accX                  float32
# accX_std              float32
# accY                  float32
# accY_std              float32
# accZ                  float32
# accZ_std              float32
# gyrX                  float32
# gyrX_std              float32
# gyrY                  float32
# gyrY_std              float32
# gyrZ                  float32
# gyrZ_std              float32
# heartR                float32
# heartR_std            float32
# AirTemperature        float32
# AT_std                float32
# PlethysmogramGreen    float32
# ple_std               float32
# mood                  float32
# tense                 float32
# tired                 float32
# rumination            float32
# socialize             float32
# socialize_val         float32
# work_time             float32
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# first algorithm
train_set, test_set = train_test_split(data_2, test_size=0.25, random_state=42, shuffle=True)
train_set_3, test_set_3 = train_test_split(data_3, test_size=0.25, random_state=42, shuffle=True)

# %%
X_train_3 = train_set_3.loc[:,'accX':'work_time']
y_train_31 = train_set_3.loc[:, ['phq_1']].values.ravel()
y_train_32 = train_set_3.loc[:, ['phq_2']].values.ravel()

X_train = train_set.loc[:,'accX':'day_sleep']
y_train_1 = train_set[['phq_1']].values.ravel()
y_train_2 = train_set[['phq_2']].values.ravel()

# %%
X_test_3 = test_set_3.loc[:,'accX':'work_time']
y_test_31 = test_set_3[['phq_1']].values.ravel()
y_test_32 = test_set_3[['phq_2']].values.ravel()

X_test = test_set.loc[:,'accX':'day_sleep']
y_test_1 = test_set[['phq_1']].values.ravel()
y_test_2 = test_set[['phq_2']].values.ravel()

# %%
X_train.head()
# Out:
#         accX  accX_std  accY  accY_std  accZ  accZ_std  gyrX  gyrX_std  gyrY  \
# 75197  -5.71      0.03  3.80      0.03 -7.29      0.03 -0.07      0.11  0.04
# 106119  6.41      0.03 -4.11      0.04  6.07      0.04 -0.08      0.26 -0.31
# 82523  -1.82      0.03 -9.57      0.03  1.52      0.03 -0.11      0.23  0.04
# 77584   1.50      0.03 -9.47      0.03  2.11      0.03 -0.05      0.16 -0.04
# 95144   1.94      0.03 -9.56      0.03 -0.25      0.03 -0.06      0.43  0.06
#
#         gyrY_std  ...  mood  tense  tired  period  rumination  socialize  \
# 75197       0.10  ...     3      2      0       0           7         90
# 106119      0.31  ...     1      1      1       0           5          8
# 82523       0.13  ...     3      4      2       0           5         66
# 77584       0.08  ...     3      4      1       0           7         88
# 95144       0.26  ...     3      3      3       0           6         83
#
#         socialize_val  sport_time  work_time  day_sleep
# 75197              50           0        110          0
# 106119             91           0        220          0
# 82523              58           0        225          0
# 77584              57           0        155          0
# 95144              68           0         85          0
#
# [5 rows x 28 columns]

# %%
# for data 2
rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=30, n_jobs=-1 ,oob_score=True)
rnd_clf.fit(X_train, y_train_1)
# y_pred_rf = rnd_clf.predict(X_test)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=30,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
# for data 2
rnd_clf_3 = RandomForestClassifier(n_estimators=500, max_leaf_nodes=35, n_jobs=-1 ,oob_score=True)
rnd_clf_3.fit(X_train_3, y_train_31)
y_pred_rf_3 = rnd_clf_3.predict(X_test_3)

# %%
accuracy_score(y_test_1, y_pred_rf)
# Out:
# 0.7268438124569968

# %%
rnd_clf.oob_score_
# Out:
# 0.7226499787031879

# %%
accuracy_score(y_test_31, y_pred_rf_3)
# Out:
# 0.9199895154156155

# %%
rnd_clf_3.oob_score_
# Out:
# 0.9187226281358191

# %%
def display_scores(score):
    print('scores:', score)
    print('Mean:', score.mean())
    print('std dev:', score.std())

# %%
# k fold to see overfitting
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rnd_clf_3, X_train, y_train_1, cv=10)

display_scores(scores)
# Out:
# scores: [0.91944111 0.9069869  0.91329985 0.91525609 0.91732197 0.92004369
#  0.92735416 0.92003496 0.92374918 0.91992572]
# Mean: 0.9183413626343102
# std dev: 0.00533722432918766

# %%
# k fold to see overfitting
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rnd_clf, X_train, y_train_1, cv=10)

display_scores(scores)
# Out:
# scores: [0.78506713 0.780131   0.77822669 0.78475483 0.7967453  0.7915893
#  0.79779331 0.78359187 0.77736509 0.79298667]
# Mean: 0.786825120088474
# std dev: 0.007109433174893361

# %%
for name, score in zip(X.columns, rnd_clf.feature_importances_):
    print(name, score)
# Out:
# accX 0.0011424529820211816
# accX_std 0.0
# accY 0.011500327628622433
# accY_std 0.0
# accZ 0.0002437459414303
# accZ_std 1.980920118574002e-05
# gyrX 0.0
# gyrX_std 7.62750478092124e-06
# gyrY 0.0
# gyrY_std 0.0
# gyrZ 0.0
# gyrZ_std 0.0
# heartR 0.00021382224132304004
# AirTemperature 0.0008297386752951483
# AT_std 2.8356366123221114e-05
# PlethysmogramGreen 0.006157689452004151
# ple_std 0.0023156061907457465
# alc 0.04109601562173688
# mood 0.11139086307230553
# tense 0.16976186912233004
# tired 0.10201723174248718
# period 0.034533156395099775
# rumination 0.08149356852967314
# socialize 0.1617831337910413
# socialize_val 0.16823471248813543
# sport_time 0.0387825499393583
# work_time 0.06844772311430034

# %%
rnd_clf_2 = RandomForestClassifier(n_estimators=500, max_leaf_nodes=25, n_jobs=-1,oob_score=True)
rnd_clf_2.fit(X_train, y_train_2)
y_pred_rf = rnd_clf_2.predict(X_test)

# %%
accuracy_score(y_test_2, y_pred_rf)
# Out:
# 0.7552646775745909

# %%
rnd_clf_2.oob_score_
# Out:
# 0.7555261823944972

# %%
X_train_crippled = train_set.loc[:,'accX':'ple_std']
X_test_crippled = test_set.loc[:,'accX':'ple_std']
X_train_crippled
# Out:
#          accX  accX_std   accY  accY_std   accZ  accZ_std   gyrX  gyrX_std  \
# 92742   0.701     0.360  0.273     0.204  0.449     0.204  0.293     0.134
# 135128  0.401     0.234  0.288     0.433  0.542     0.433  0.289     0.055
# 74545   0.703     0.003  0.086     0.003  0.623     0.003  0.289     0.002
# 145738  0.454     0.312  0.162     0.181  0.539     0.181  0.287     0.250
# 113282  0.545     0.001  0.502     0.001  0.998     0.001  0.290     0.000
# ...       ...       ...    ...       ...    ...       ...    ...       ...
# 119879  0.721     0.112  0.280     0.338  0.517     0.338  0.291     0.075
# 103694  0.610     0.117  0.105     0.206  0.754     0.206  0.286     0.215
# 131932  0.223     0.006  0.340     0.012  0.551     0.012  0.292     0.016
# 146867  0.594     0.180  0.231     0.251  0.265     0.251  0.290     0.141
# 121958  0.498     0.150  0.756     0.255  0.172     0.255  0.286     0.130
#
#          gyrY  gyrY_std   gyrZ  gyrZ_std  heartR  AirTemperature  AT_std  \
# 92742   0.360     0.101  0.487     0.127   0.355           0.604   0.030
# 135128  0.357     0.033  0.490     0.056   0.193           0.490   0.010
# 74545   0.358     0.001  0.489     0.001   0.199           0.624   0.015
# 145738  0.376     0.189  0.485     0.182   0.316           0.494   0.010
# 113282  0.357     0.000  0.490     0.000   0.376           0.495   0.015
# ...       ...       ...    ...       ...     ...             ...     ...
# 119879  0.358     0.062  0.490     0.077   0.162           0.451   0.005
# 103694  0.347     0.178  0.489     0.204   0.199           0.581   0.010
# 131932  0.359     0.007  0.489     0.005   0.327           0.409   0.036
# 146867  0.358     0.079  0.490     0.078   0.199           0.544   0.005
# 121958  0.354     0.098  0.491     0.080   0.276           0.573   0.005
#
#         PlethysmogramGreen  ple_std
# 92742                0.646    0.156
# 135128               0.436    0.064
# 74545                0.805    0.024
# 145738               0.812    0.108
# 113282               0.436    0.051
# ...                    ...      ...
# 119879               0.524    0.159
# 103694               0.497    0.072
# 131932               0.895    0.000
# 146867               0.895    0.000
# 121958               0.504    0.022
#
# [155849 rows x 17 columns]

# %%
rnd_clf_crippled = RandomForestClassifier(n_estimators=500, max_leaf_nodes=25, n_jobs=-1,oob_score=True)
rnd_clf_crippled.fit(X_train_crippled, y_train_1)
y_pred_cr = rnd_clf_crippled.predict(X_test_crippled)

# %%
accuracy_score(y_test_1, y_pred_cr)
# Out:
# 0.25847930702598654

# %%
rnd_clf_crippled.oob_score_
# Out:
# 0.2591803604771285

# %%
for name, score in zip(X_train_crippled.columns, rnd_clf_crippled.feature_importances_):
    print(name, score)
# Out:
# accX 0.07583058445387814
# accX_std 0.013688658855425582
# accY 0.2886765394752981
# accY_std 0.015599456048933192
# accZ 0.08254821682967342
# accZ_std 0.01524922150692262
# gyrX 0.003436130093115518
# gyrX_std 0.007995858185376872
# gyrY 0.005685684873382271
# gyrY_std 0.006361533274272587
# gyrZ 0.0033329151293537483
# gyrZ_std 0.007517580620873957
# heartR 0.029639315071687444
# AirTemperature 0.13883560949389395
# AT_std 0.006212384456588675
# PlethysmogramGreen 0.2143004996952625
# ple_std 0.08508981193606145

# %%
line = ''
len(line)
# Out:
# 0

# %%
liens = []

len(liens[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-368-14916f5f2450> in <module>
#       1 liens = []
#       2
# ----> 3 len(liens[0])
#
# IndexError: list index out of range
